# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
p = np.fromfile('p.bin',dtype='float32')

# %%
p1 = p[0*50:(5000)]

# %%
p1 = p1.reshape(50, 100)

# %%
plt.imshow(p1)
